# %% [markdown]
# <a href="https://colab.research.google.com/github/straj-granicy/ML-Stepik/blob/master/210125_stepik_Karpov_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
students_p=pd.read_csv('StudentsPerformance.csv')

# %%
students_p
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]

# %% [markdown]
# вывести первые строчек - 5

# %%
students_p.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %% [markdown]
# вывести первые строчек - 10

# %%
students_p.head(10)
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
# 5  female        group B  ...            83            78
# 6  female        group B  ...            95            92
# 7    male        group B  ...            43            39
# 8    male        group D  ...            64            67
# 9  female        group B  ...            60            50
#
# [10 rows x 8 columns]

# %% [markdown]
# посмотреть конец таблицы

# %%
students_p.tail(10)
# Out:
#      gender race/ethnicity  ... reading score writing score
# 990    male        group E  ...            81            75
# 991  female        group B  ...            82            78
# 992  female        group D  ...            76            76
# 993  female        group D  ...            72            74
# 994    male        group A  ...            63            62
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [10 rows x 8 columns]

# %% [markdown]
# # описательная статистика для переменных.
# # переменные, представленные строками, в табличку не попали.

# %%
students_p.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# типы данных
#
# *   int64 - количественные переменные
# *   object - грубо говоря данные, которые хранятся в виде строк.

# %%
students_p.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# сколько строчек и колонок

# %%
students_p.shape
# Out:
# (1000, 8)

# %% [markdown]
# размер датафрейма - число строчек, умноженное на число колонок.

# %%
students_p.size
# Out:
# 8000

# %% [markdown]
# НБ - методы - там где скобки - позволяют что-то сделать с данными, преобразовать. аттрибуты - где без скобок - посмотреть на данные.

# %% [markdown]
# отбор строчек и колонок из датафрейма

# %% [markdown]
# первые 5 наблюдний и первые 3 колонки. можно по именам, можно по индексам. индексация в питоне начинается с нуля.

# %% [markdown]
# iloc - отбор по местонахождению, там где строки, столбцы находятся. сначала строки, потом столбцы - integer location

# %%
students_p.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %% [markdown]
# можно указать индексы конкретных колонокю для этого множественные запросы оборачиваем в отдельный список. - 1 - последняя колонкаю отрицательные индексы можно использовать, чтобы двигаться справа налево.

# %%
students_p.iloc[[0,2,4], [1,2,-1]]
# Out:
#   race/ethnicity parental level of education  writing score
# 0        group B           bachelor's degree             74
# 2        group B             master's degree             93
# 4        group C                some college             75

# %%
students_p.iloc[[0,2,4], [-1,-2,-3]]
# Out:
#    writing score  reading score  math score
# 0             74             72          72
# 2             93             95          90
# 4             75             78          76

# %% [markdown]
# ```
# loc - для доступа по лейблам.
# 1. делаем отдельный датафрейм.
# 2. отбираем колонки с iloc.
#
# ```

# %%
students_p_with_names=students_p.iloc[[0,3,5]]

# %%
students_p_with_names
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 3    male        group A  ...            57            44
# 5  female        group B  ...            83            78
#
# [3 rows x 8 columns]

# %%
students_p_with_names.index=['Peter','Jack','John']

# %%
students_p_with_names.loc[['Peter','John']]
# Out:
#        gender race/ethnicity  ... reading score writing score
# Peter  female        group B  ...            72            74
# John   female        group B  ...            83            78
#
# [2 rows x 8 columns]

# %%
students_p_with_names.loc[['Peter','John'],['gender','writing score']]
# Out:
#        gender  writing score
# Peter  female             74
# John   female             78

# %% [markdown]
# # Фильтрация данных

# %% [markdown]
# отберем 1-ую колонку

# %%
students_p_with_names.iloc[:,0]
# Out:
# Peter    female
# Jack       male
# John     female
# Name: gender, dtype: object

# %% [markdown]
# узнаем тип данных. это Pandas Series - одномерный массив с лейблами-именами.

# %%
type(students_p_with_names.iloc[:,0])
# Out:
# pandas.core.series.Series

# %%
type(students_p_with_names.loc[['Peter','John'],['gender','writing score']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# создадим пандовскую серию

# %%
pd.Series([0,2,5])
# Out:
# 0    0
# 1    2
# 2    5
# dtype: int64

# %% [markdown]
# добавим лейблы

# %%
my_series1 = pd.Series([0,2,5], index=['Peter','Jack','John'])

# %%
my_series1меня
# Out:
# Peter    0
# Jack     2
# John     5
# dtype: int64

# %% [markdown]
# сделаем еще одну серию, потом создадим датафрейм из 2 серий.

# %%
my_series2 = pd.Series([0,4,8], index=['Peter','Jack','John'])

# %%
pd.DataFrame({'col1':my_series1,'col2':my_series2})
# Out:
#        col1  col2
# Peter     0     0
# Jack      2     4
# John      5     8

# %% [markdown]
# в зависимости от того, как сформирован запрос, возвращается или серия или датафрейм.

# %%
students_p_with_names['gender']
# Out:
# Peter    female
# Jack       male
# John     female
# Name: gender, dtype: object

# %%
students_p_with_names[['gender']]
# Out:
#        gender
# Peter  female
# Jack     male
# John   female

# %% [markdown]
# ***Query***

# %%
students_p.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
students_p.gender=='female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %% [markdown]
# обращаемся к серии по ключу

# %%
students_p['writing score']
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %% [markdown]
# вычисляем среднее

# %%
students_p['writing score'].mean()
# Out:
# 68.054

# %%
mean_writing_score=students_p['writing score'].mean()

# %%
students_p.loc[students_p['writing score']>mean_writing_score]
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 4      male        group C  ...            78            75
# 5    female        group B  ...            83            78
# ..      ...            ...  ...           ...           ...
# 992  female        group D  ...            76            76
# 993  female        group D  ...            72            74
# 995  female        group E  ...            99            95
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [512 rows x 8 columns]

# %%
students_p.loc[students_p.gender=='female']
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# ..      ...            ...  ...           ...           ...
# 993  female        group D  ...            72            74
# 995  female        group E  ...            99            95
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [518 rows x 8 columns]

# %% [markdown]
# ***фильтрация по нескольким условиям сразу***

# %%
query=(students_p['writing score']>mean_writing_score)&(students_p['gender']=='female')

# %%
students_p.loc[query]
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# ..      ...            ...  ...           ...           ...
# 992  female        group D  ...            76            76
# 993  female        group D  ...            72            74
# 995  female        group E  ...            99            95
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [333 rows x 8 columns]

# %% [markdown]
# У какой доли студентов из датасэта в колонке lunch указано free/reduced?
#
# Формат ответа десятичная дробь, например, 0.25

# %%
students_p.lunch=='free/reduced'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997     True
# 998    False
# 999     True
# Name: lunch, Length: 1000, dtype: bool

# %%
free_lunch=students_p.lunch=='free/reduced'

# %%
free_lunch.value_counts(normalize=True)
# Out:
# False    0.645
# True     0.355
# Name: lunch, dtype: float64

# %% [markdown]
# Как различается среднее и дисперсия оценок по предметам у групп студентов со стандартным или урезанным ланчем?

# %%
students_p.iloc[:,[-1,-2,-3]]
# Out:
#      writing score  reading score  math score
# 0               74             72          72
# 1               88             90          69
# 2               93             95          90
# 3               44             57          47
# 4               75             78          76
# ..             ...            ...         ...
# 995             95             99          88
# 996             55             55          62
# 997             65             71          59
# 998             77             78          68
# 999             86             86          77
#
# [1000 rows x 3 columns]

# %%
subjects=students_p.iloc[:,[-1,-2,-3]]

# %%
subjects.describe()
# Out:
#        writing score  reading score  math score
# count    1000.000000    1000.000000  1000.00000
# mean       68.054000      69.169000    66.08900
# std        15.195657      14.600192    15.16308
# min        10.000000      17.000000     0.00000
# 25%        57.750000      59.000000    57.00000
# 50%        69.000000      70.000000    66.00000
# 75%        79.000000      79.000000    77.00000
# max       100.000000     100.000000   100.00000

# %%
subjects.var()
# Out:
# writing score    230.907992
# reading score    213.165605
# math score       229.918998
# dtype: float64

# %%
subjects.mean()
# Out:
# writing score    68.054
# reading score    69.169
# math score       66.089
# dtype: float64

# %%
mean_math_score=students_p['math score'].mean()

# %%
mean_reading_score=students_p['reading score'].mean()

# %%
query_free=(students_p['writing score']>mean_writing_score)&(students_p['reading score']>mean_reading_score)&(students_p['math score']>mean_math_score)&(students_p['lunch']=='free/reduced')

# %%
query_standard=(students_p['writing score']>mean_writing_score)&(students_p['reading score']>mean_reading_score)&(students_p['math score']>mean_math_score)&(students_p['lunch']=='standard')

# %%
query_free.var()
# Out:
# 0.07451351351351354

# %%
query_standard.var()
# Out:
# 0.20735835835835842

# %%
query_free.mean()
# Out:
# 0.081

# %%
query_standard.mean()
# Out:
# 0.293

# %% [markdown]
# # Метод Query

# %% [markdown]
# ***Переименовываем колонки в датафрейме***

# %%
students_p=students_p \
.rename (columns = {'parental level of education':'parental_level_of_education',
        'test preparation course':'test_preparation_course',
        'math score':'math_score',
        'reading score':'reading_score',
        'writing score':'writing_score'
    })

# %%
students_p.test_preparation_course
# Out:
# 0           none
# 1      completed
# 2           none
# 3           none
# 4           none
#          ...
# 995    completed
# 996         none
# 997    completed
# 998    completed
# 999         none
# Name: test_preparation_course, Length: 1000, dtype: object

# %% [markdown]
# метод query получает на вход некий запрос, например в виде строки.

# %%
students_p.query("writing_score>74")
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 4      male        group C  ...            78            75
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# ..      ...            ...  ...           ...           ...
# 991  female        group B  ...            82            78
# 992  female        group D  ...            76            76
# 995  female        group E  ...            99            95
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [350 rows x 8 columns]

# %% [markdown]
# ***сравнение со строкой***

# %%
students_p.query("gender =='female'")
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# ..      ...            ...  ...           ...           ...
# 993  female        group D  ...            72            74
# 995  female        group E  ...            99            95
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [518 rows x 8 columns]

# %% [markdown]
# ***комбинация запросов***

# %%
students_p.query("gender =='female'& writing_score>78")
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 6    female        group B  ...            95            92
# 36   female        group D  ...            81            83
# 38   female        group D  ...            90            88
# ..      ...            ...  ...           ...           ...
# 983  female        group A  ...            87            91
# 984  female        group C  ...            75            82
# 989  female        group D  ...            86            83
# 995  female        group E  ...            99            95
# 999  female        group D  ...            86            86
#
# [186 rows x 8 columns]

# %% [markdown]
# ***комбинация запросов "или-или"***

# %%
students_p.query("gender =='female'| writing_score>78")
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# ..      ...            ...  ...           ...           ...
# 993  female        group D  ...            72            74
# 995  female        group E  ...            99            95
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [586 rows x 8 columns]

# %% [markdown]
# можно сравнить с переменной, которую создали, но для этого нужно ее экранировать.

# %%
writing_score_query=88

# %%
students_p.query(" writing_score>@writing_score_query")
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 2    female        group B  ...            95            93
# 6    female        group B  ...            95            92
# 94   female        group B  ...            86            92
# 102  female        group D  ...            91            89
# 104    male        group C  ...            86            90
# ..      ...            ...  ...           ...           ...
# 962  female        group E  ...           100           100
# 970  female        group D  ...           100           100
# 979  female        group C  ...            95            94
# 983  female        group A  ...            87            91
# 995  female        group E  ...            99            95
#
# [87 rows x 8 columns]

# %% [markdown]
# все имена колонок можно получить обернув датафрейм в функцию list

# %%
list(students_p)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course',
#  'math_score',
#  'reading_score',
#  'writing_score']

# %% [markdown]
# можно отобрать названия, где есть слово score

# %%
[i for i in list(students_p) if 'score' in i]
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
score_columns=[i for i in list(students_p) if 'score' in i]

# %%
students_p[score_columns].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ***метфильтры пандас для сравнения***

# %%
students_p.filter(like='score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# задав фильтр axis,можно выбрать будем ли мы применять фильтр по столбикам или по строчкам.
# axis=1 - столбики
# axis=0 - строчки

# %%
students_p_with_names.filter(like='J',axis=0)
# Out:
#       gender race/ethnicity  ... reading score writing score
# Jack    male        group A  ...            57            44
# John  female        group B  ...            83            78
#
# [2 rows x 8 columns]

# %% [markdown]
# # Groupby&Aggregate

# %% [markdown]
# посчитаем среднее значение скоров в зависимости от пола студента

# %% [markdown]
# среднее значение скоров по математике в зависимости от гендера

# %%
students_p.groupby('gender').aggregate({'math_score':'mean'})
# Out:
#         math_score
# gender
# female   63.633205
# male     68.728216

# %% [markdown]
# добавляем еще переменные

# %%
students_p.groupby(['gender','' as_index=False) \
.aggregate({'math_score':'mean', 'reading_score':'mean'})\
.rename(columns={'math_score':'mean_math_score', 'reading_score':'mean_reading_score'})
# Out:
#    gender  mean_math_score  mean_reading_score
# 0  female        63.633205           72.608108
# 1    male        68.728216           65.473029

# %% [markdown]
# можно групировать по нескольким признакам. для этого нужно обернуть признаки в список.

# %%
students_p.groupby(['gender','race/ethnicity'] , as_index=False) \
.aggregate({'math_score':'mean', 'reading_score':'mean'})\
.rename(columns={'math_score':'mean_math_score', 'reading_score':'mean_reading_score'})
# Out:
#    gender race/ethnicity  mean_math_score  mean_reading_score
# 0  female        group A        58.527778           69.000000
# 1  female        group B        61.403846           71.076923
# 2  female        group C        62.033333           71.944444
# 3  female        group D        65.248062           74.046512
# 4  female        group E        70.811594           75.840580
# 5    male        group A        63.735849           61.735849
# 6    male        group B        65.930233           62.848837
# 7    male        group C        67.611511           65.424460
# 8    male        group D        69.413534           66.135338
# 9    male        group E        76.746479           70.295775

# %% [markdown]
# можно сделать более многоуровневый индекс

# %%
students_p.groupby(['gender','race/ethnicity']) \
.aggregate({'math_score':'mean', 'reading_score':'mean'})\
.rename(columns={'math_score':'mean_math_score', 'reading_score':'mean_reading_score'})
# Out:
#                        mean_math_score  mean_reading_score
# gender race/ethnicity
# female group A               58.527778           69.000000
#        group B               61.403846           71.076923
#        group C               62.033333           71.944444
#        group D               65.248062           74.046512
#        group E               70.811594           75.840580
# male   group A               63.735849           61.735849
#        group B               65.930233           62.848837
#        group C               67.611511           65.424460
#        group D               69.413534           66.135338
#        group E               76.746479           70.295775

# %%
mean_scores=students_p.groupby(['gender','race/ethnicity']) \
.aggregate({'math_score':'mean', 'reading_score':'mean'})\
.rename(columns={'math_score':'mean_math_score', 'reading_score':'mean_reading_score'})

# %%
mean_scores.index
# Out:
# MultiIndex([('female', 'group A'),
#             ('female', 'group B'),
#             ('female', 'group C'),
#             ('female', 'group D'),
#             ('female', 'group E'),
#             (  'male', 'group A'),
#             (  'male', 'group B'),
#             (  'male', 'group C'),
#             (  'male', 'group D'),
#             (  'male', 'group E')],
#            names=['gender', 'race/ethnicity'])

# %% [markdown]
# для выделения данных в мультииндексе нужно сначала указывать индекс 1-ого уровня, потом 2-ого.
# для введения 2 значений - оборачиваем в список.

# %%
mean_scores.loc[[('female', 'group A'), ('female','group B')]]
# Out:
#                        mean_math_score  mean_reading_score
# gender race/ethnicity
# female group A               58.527778           69.000000
#        group B               61.403846           71.076923

# %% [markdown]
# в мультииндексе есть преимущества. к пандовским сериям можно применять крутые фишки например, вывести уникальные значения.

# %%
students_p.math_score.unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %% [markdown]
# посчитать числов уникальных значений

# %%
students_p.math_score.nunique()
# Out:
# 81

# %% [markdown]
# считаем кол-во уникальных значений на пересечении 2 груп.

# %%
students_p.groupby(['gender','race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %% [markdown]
# groupby можно комбинировать не только с aggregate но и с другими методами.

# %% [markdown]
# найдем топ 5 математиков девушек и парней.
# отсортируем переменные по переменной gender, math_score

# %%
students_p.sort_values(['gender', 'math_score'])
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 59   female        group C  ...            17            10
# 980  female        group B  ...            24            23
# 17   female        group B  ...            32            28
# 787  female        group B  ...            38            32
# 145  female        group C  ...            39            33
# ..      ...            ...  ...           ...           ...
# 306    male        group E  ...            87            81
# 149    male        group E  ...           100            93
# 623    male        group A  ...            96            86
# 625    male        group D  ...            97            99
# 916    male        group E  ...           100           100
#
# [1000 rows x 8 columns]

# %%
students_p.sort_values(['gender', 'math_score'], ascending=False) \
.groupby('gender').head(5)
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 149    male        group E  ...           100            93
# 623    male        group A  ...            96            86
# 625    male        group D  ...            97            99
# 916    male        group E  ...           100           100
# 306    male        group E  ...            87            81
# 451  female        group E  ...            92            97
# 458  female        group E  ...           100           100
# 962  female        group E  ...           100           100
# 114  female        group E  ...           100           100
# 263  female        group E  ...            93            90
#
# [10 rows x 8 columns]

# %% [markdown]
# ***как создавать новые колонки в датафрейме***

# %% [markdown]
# ```
# создадим колонку с тотальной успеваемостью студентов - total_score.
# серии можно складывать друг с другом
# ```

# %%
students_p['total_score'] = students_p.math_score+students_p.reading_score+students_p.writing_score

# %%
students_p.math_score+students_p.reading_score+students_p.writing_score
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %% [markdown]
# посмотрим на итоговый датафрейм. появится новая колонка

# %%
students_p.head()
# Out:
#    gender race/ethnicity  ... writing_score total_score
# 0  female        group B  ...            74         218
# 1  female        group C  ...            88         247
# 2  female        group B  ...            93         278
# 3    male        group A  ...            44         148
# 4    male        group C  ...            75         229
#
# [5 rows x 9 columns]

# %% [markdown]
# *можно делать и другие операции. например, умножим серию на 2*

# %%
students_p.math_score*2
# Out:
# 0      144
# 1      138
# 2      180
# 3       94
# 4      152
#       ...
# 995    176
# 996    124
# 997    118
# 998    136
# 999    154
# Name: math_score, Length: 1000, dtype: int64

# %% [markdown]
# для множественных преобразований есть метод assign

# %%
students_p = students_p.assign(total_score_log=np.log(students_p.total_score))

# %%
students_p
# Out:
#      gender race/ethnicity  ... total_score total_score_log
# 0    female        group B  ...         218        5.384495
# 1    female        group C  ...         247        5.509388
# 2    female        group B  ...         278        5.627621
# 3      male        group A  ...         148        4.997212
# 4      male        group C  ...         229        5.433722
# ..      ...            ...  ...         ...             ...
# 995  female        group E  ...         282        5.641907
# 996    male        group C  ...         172        5.147494
# 997  female        group C  ...         195        5.273000
# 998  female        group D  ...         223        5.407172
# 999  female        group D  ...         249        5.517453
#
# [1000 rows x 10 columns]

# %% [markdown]
# удаляем ***колонки*** - метод drop

# %%
students_p.drop(['total_score'] , axis=1)
# Out:
#      gender race/ethnicity  ... writing_score total_score_log
# 0    female        group B  ...            74        5.384495
# 1    female        group C  ...            88        5.509388
# 2    female        group B  ...            93        5.627621
# 3      male        group A  ...            44        4.997212
# 4      male        group C  ...            75        5.433722
# ..      ...            ...  ...           ...             ...
# 995  female        group E  ...            95        5.641907
# 996    male        group C  ...            55        5.147494
# 997  female        group C  ...            65        5.273000
# 998  female        group D  ...            77        5.407172
# 999  female        group D  ...            86        5.517453
#
# [1000 rows x 9 columns]

# %% [markdown]
# Пересчитаем число ног у героев игры Dota2! Сгруппируйте героев из датасэта по числу их ног (колонка legs), и заполните их число в задании ниже.
#
# Данные взяты отсюда, на этом же сайте можно найти больше разнообразных данных по Dota2.

# %%
dota=pd.read_csv('dota_hero_stats.csv')

# %%
dota
# Out:
#      Unnamed: 0  ...                                              roles
# 0             0  ...                       ['Carry', 'Escape', 'Nuker']
# 1             1  ...    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2             2  ...        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3             3  ...  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4             4  ...        ['Support', 'Disabler', 'Nuker', 'Jungler']
# ..          ...  ...                                                ...
# 112         112  ...       ['Carry', 'Escape', 'Disabler', 'Initiator']
# 113         113  ...         ['Support', 'Nuker', 'Disabler', 'Escape']
# 114         114  ...  ['Carry', 'Nuker', 'Disabler', 'Durable', 'Esc...
# 115         115  ...         ['Support', 'Nuker', 'Disabler', 'Escape']
# 116         116  ...      ['Carry', 'Initiator', 'Disabler', 'Durable']
#
# [117 rows x 8 columns]

# %%
dota.nunique()
# Out:
# Unnamed: 0        117
# attack_type         2
# id                117
# legs                5
# localized_name    117
# name              117
# primary_attr        3
# roles             100
# dtype: int64

# %%
legs=dota.groupby('legs').nunique()

# %%
legs
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11            2  11              11    11             3     11
# 2             95            2  95              95    95             3     81
# 4              7            2   7               7     7             3      7
# 6              3            2   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
dota['legs'].value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %% [markdown]
# К нам поступили данные из бухгалтерии о заработках Лупы и Пупы за разные задачи! Посмотрите у кого из них больше средний заработок в различных категориях (колонка Type) и заполните таблицу, указывая исполнителя с большим заработком в каждой из категорий.

# %%
account=pd.read_csv('accountancy.csv')

# %%
account.head(5)
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
account.groupby(['Type','Executor']) \
.aggregate({'Salary':'mean'})
# Out:
#                    Salary
# Type Executor
# A    Loopa      58.000000
#      Pupa      160.833333
# B    Loopa     145.166667
#      Pupa       77.000000
# C    Loopa     154.333333
#      Pupa       74.500000
# D    Loopa     137.714286
#      Pupa      146.500000
# E    Loopa     164.000000
#      Pupa      131.200000
# F    Loopa     238.000000
#      Pupa      136.250000

# %% [markdown]
# Продолжим исследование героев Dota2. Сгруппируйте по колонкам attack_type и primary_attr и выберите самый распространённый набор характеристик.

# %%
dota
# Out:
#      Unnamed: 0  ...                                              roles
# 0             0  ...                       ['Carry', 'Escape', 'Nuker']
# 1             1  ...    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2             2  ...        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3             3  ...  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4             4  ...        ['Support', 'Disabler', 'Nuker', 'Jungler']
# ..          ...  ...                                                ...
# 112         112  ...       ['Carry', 'Escape', 'Disabler', 'Initiator']
# 113         113  ...         ['Support', 'Nuker', 'Disabler', 'Escape']
# 114         114  ...  ['Carry', 'Nuker', 'Disabler', 'Durable', 'Esc...
# 115         115  ...         ['Support', 'Nuker', 'Disabler', 'Escape']
# 116         116  ...      ['Carry', 'Initiator', 'Disabler', 'Durable']
#
# [117 rows x 8 columns]

# %%
query = dota.groupby(['attack_type','primary_attr'])

# %%
query.describe()
# Out:
#                          Unnamed: 0                        ... legs
#                               count       mean        std  ...  50%  75%  max
# attack_type primary_attr                                   ...
# Melee       agi                19.0  61.315789  38.233279  ...  2.0  2.0  8.0
#             int                 2.0  67.500000  20.506097  ...  2.0  2.0  2.0
#             str                35.0  62.657143  34.265351  ...  2.0  2.0  6.0
# Ranged      agi                18.0  46.111111  32.737618  ...  2.0  2.0  4.0
#             int                40.0  55.225000  32.472069  ...  2.0  2.0  6.0
#             str                 3.0  84.666667  25.774665  ...  2.0  2.0  2.0
#
# [6 rows x 24 columns]

# %%
query.count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %% [markdown]
# Аспирант Ростислав изучает метаболом водорослей и получил такую табличку. В ней он записал вид каждой водоросли, её род (группа, объединяющая близкие виды), группа (ещё одно объединение водорослей в крупные фракции) и концентрации анализируемых веществ.
#
# Помогите Ростиславу найти среднюю концентрацию каждого из веществ в каждом из родов (колонка genus)! Для этого проведите группировку датафрэйма, сохранённого в переменной concentrations, и примените метод, сохранив результат в переменной mean_concentrations

# %%
bio=pd.read_csv('algae.csv')

# %%
bio.head(5)
# Out:
#                species       genus  group  ...   citrate   glucose  oleic_acid
# 0    Fucus_vesiculosus       Fucus  brown  ...  5.004262  2.548459    6.405165
# 1  Saccharina_japonica  Saccharina  brown  ...  5.621499  6.013219    4.156700
# 2       Fucus_serratus       Fucus  brown  ...  1.216767  3.623225    0.304573
# 3      Fucus_distichus       Fucus  brown  ...  6.423606  2.272724    3.393203
# 4    Cladophora_fracta  Cladophora  green  ...  6.940588  2.316955    2.528886
#
# [5 rows x 8 columns]

# %%
concentrations.head()
# Out:
#                 species        genus  group  ...   citrate   glucose  oleic_acid
# 0     Fucus_vesiculosus        Fucus  brown  ...  5.004262  2.548459    6.405165
# 1   Saccharina_japonica   Saccharina  brown  ...  5.621499  6.013219    4.156700
# 2        Fucus_serratus        Fucus  brown  ...  1.216767  3.623225    0.304573
# 3       Fucus_distichus        Fucus  brown  ...  6.423606  2.272724    3.393203
# 4     Cladophora_fracta   Cladophora  green  ...  6.940588  2.316955    2.528886
# 5   Cladophora_compacta   Cladophora  green  ...  3.082826  3.343707    1.432514
# 6   Cladophora_gracilis   Cladophora  green  ...  5.841520  2.740165    2.829016
# 7      Palmaria_palmata     Palmaria    red  ...  5.573905  3.242090    2.245538
# 8  Saccharina_latissima   Saccharina  brown  ...  1.071920  3.947968    4.817804
# 9   Ascophyllum_nodosum  Ascophyllum  brown  ...  5.253527  3.414961    2.432526
#
# [10 rows x 8 columns]

# %%
bio.groupby('genus')

# %%
bio.groupby('genus') \
.aggregate({'sucrose':'mean', 'citrate':'mean' , 'glucose':'mean' , 'oleic_acid':'mean'})
# Out:
#               sucrose   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  5.253527  3.414961    2.432526
# Cladophora   4.008792  5.288311  2.800276    2.263472
# Fucus        4.355112  4.214878  2.814803    3.367647
# Palmaria     0.704580  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.346710  4.980594    4.487252

# %% [markdown]
# ```
#
#
# Пользуясь предыдущими данными, укажите через пробел (без запятых) чему равны минимальная, средняя и максимальная концентрации аланина (alanin) среди видов рода Fucus. Округлите до 2-ого знака, десятичным разделителем является точка.
#
# Формат ответа:
# 0.55 6.77 7.48
#
# ```

# %%
bio.query("genus =='Fucus'")
# Out:
#              species  genus  group  ...   citrate   glucose  oleic_acid
# 0  Fucus_vesiculosus  Fucus  brown  ...  5.004262  2.548459    6.405165
# 2     Fucus_serratus  Fucus  brown  ...  1.216767  3.623225    0.304573
# 3    Fucus_distichus  Fucus  brown  ...  6.423606  2.272724    3.393203
#
# [3 rows x 8 columns]

# %%
q2=bio.query("genus =='Fucus'")

# %%
q2.describe().round(2)
# Out:
#        sucrose  alanin  citrate  glucose  oleic_acid
# count     3.00    3.00     3.00     3.00        3.00
# mean      4.36    3.57     4.21     2.81        3.37
# std       2.11    3.15     2.69     0.71        3.05
# min       3.00    0.35     1.22     2.27        0.30
# 25%       3.14    2.03     3.11     2.41        1.85
# 50%       3.28    3.71     5.00     2.55        3.39
# 75%       5.03    5.18     5.71     3.09        4.90
# max       6.79    6.64     6.42     3.62        6.41

# %%
bio
# Out:
#                 species        genus  group  ...   citrate   glucose  oleic_acid
# 0     Fucus_vesiculosus        Fucus  brown  ...  5.004262  2.548459    6.405165
# 1   Saccharina_japonica   Saccharina  brown  ...  5.621499  6.013219    4.156700
# 2        Fucus_serratus        Fucus  brown  ...  1.216767  3.623225    0.304573
# 3       Fucus_distichus        Fucus  brown  ...  6.423606  2.272724    3.393203
# 4     Cladophora_fracta   Cladophora  green  ...  6.940588  2.316955    2.528886
# 5   Cladophora_compacta   Cladophora  green  ...  3.082826  3.343707    1.432514
# 6   Cladophora_gracilis   Cladophora  green  ...  5.841520  2.740165    2.829016
# 7      Palmaria_palmata     Palmaria    red  ...  5.573905  3.242090    2.245538
# 8  Saccharina_latissima   Saccharina  brown  ...  1.071920  3.947968    4.817804
# 9   Ascophyllum_nodosum  Ascophyllum  brown  ...  5.253527  3.414961    2.432526
#
# [10 rows x 8 columns]

# %%
q3=bio.groupby('group')

# %% [markdown]
# Дисперсия концентрации цитрата в бурых, зелёных и красных водорослях

# %%
q3.var().round(2)
# Out:
#        sucrose  alanin  citrate  glucose  oleic_acid
# group
# brown     5.46    7.22     5.47     1.77        4.39
# green     2.67    7.06     3.95     0.27        0.54
# red        NaN     NaN      NaN      NaN         NaN

# %% [markdown]
# Размах (максимум - минимум) сахарозы в бурых, зелёных и красных водорослях

# %%
q3.aggregate(np.ptp).round(2)
# Out:
#        sucrose  alanin  citrate  glucose  oleic_acid
# group
# brown     5.19    6.29     5.35     3.74         6.1
# green     3.26    5.23     3.86     1.03         1.4
# red       0.00    0.00     0.00     0.00         0.0

# %% [markdown]
# Число видов бурых, зелёных и красных водорослей

# %%
q3.nunique()
# Out:
#        species  genus  sucrose  alanin  citrate  glucose  oleic_acid
# group
# brown        6      3        6       6        6        6           6
# green        3      1        3       3        3        3           3
# red          1      1        1       1        1        1           1

# %% [markdown]
# #  Визуализация, seaborn, почти также круто, как ggplot2

# %% [markdown]
# В этом уроке мы рассмотрим крайне важную часть анализа данных - визуализацию
# seaborn надстройка над matplotlib
# в пандас можно без проблем построить гистограму или скэтер плот.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# построим гистограму распределения с помощью метода hist()

# %%
students_p.math_score.hist()

# %% [markdown]
# https://python-school.ru/data-vizualization-basic-pandas/
# Линейный график строит переход от точки к точке.

# %%
students_p.math_score.plot()

# %% [markdown]
# рисуем скэтэр плот. получим график корреляции между 2-мя переменными.

# %%
students_p.plot.scatter(x='math_score',y='reading_score')

# %% [markdown]
# рисуем скэтэр плот с seaborn
# hue - групирующая переменная
# fit_reg=False - без регрессионной прямой

# %%
sns.lmplot(x='math_score',y='reading_score', hue='gender', data=students_p)

# %%
sns.lmplot(x='math_score',y='reading_score', hue='gender', data=students_p, fit_reg=False)

# %% [markdown]
# как подписать оси.

# %%
ax=sns.lmplot(x='math_score',y='reading_score', hue='gender', data=students_p, fit_reg=False)
ax.set_xlabels('Math Scores')
ax.set_ylabels('Reading Scores')

# %% [markdown]
# Представьте, что у вас есть датафрэйм df, хранящий данные о зарплате за месяц, со всего 1-ой колонкой income.
#
# Укажите верные способы, как отрисовать простой график зависимости зарплаты от даты (то, как отображается дата сейчас не важно, главное сам график)
#
# Убедитесь, что вы используте версию seaborn > = 0.9.

# %%
salary=pd.read_csv('income.csv')

# %%
salary.head(5)
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
salary.income.plot()

# %%
sns.lineplot(data=salary)

# %%
salary.plot()

# %%
plt.plot(salary.index, salary.income)

# %%
sns.lineplot(x=salary.index, y=salary.income)

# %%
salary['income'].plot()

# %%
salary.plot(kind='line')

# %%
df=pd.read_csv('dataset_209770_6(1).txt', sep=" ")

# %%
df.head()
# Out:
#              x            y
# 0   904.508307  1194.271923
# 1  1107.919702   899.477829
# 2  1291.211108   693.623260
# 3   306.432713  1298.499604
# 4  1004.017921  1386.390648

# %%
sns.lmplot(x='x',y='y', data=df)

# %%
sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Да, верно) Один из вариантов построения графика -
#
# df = pd.read_csv('path_to_dataset', sep=' ', header=None)
# sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])

# %% [markdown]
# Скачайте данные, представляющие геномные расстояния между видами, и постройте тепловую карту, чтобы различия было видно наглядно. В ответ впишите, какая картинка соответствует скачанным данным.
#
# Чтобы график отображался как на картинках, добавьте
#
# g = # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
# g.xaxis.set_ticks_position('top')
# g.xaxis.set_tick_params(rotation=90)

# %%
genome=pd.read_csv('genome_matrix.csv', index_col=0)

# %%
genome
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
heatmap=sns.heatmap(data=genome,cmap="viridis")

# %% [markdown]
# Пришло время узнать, кто самый главный рак какая роль в dota самая распространённая. Скачайте датасэт с данными о героях из игры dota 2 и посмотрите на распределение их возможных ролей в игре (колонка roles). Постройте гистограмму, отражающую скольким героям сколько ролей приписывается (по мнению Valve, конечно) и напишите какое число ролей у большинства героев.
#
# Это задание можно выполнить многими путями, и рисовать гистограмму вообще говоря для этого не нужно.
#
# Данные взяты отсюда, на этом же сайте можно найти больше разнообразных данных по dota 2

# %%
dota.head(5)
# Out:
#    Unnamed: 0  ...                                         roles
# 0           0  ...                        [Carry, Escape, Nuker]
# 1           1  ...       [Initiator, Durable, Disabler, Jungler]
# 2           2  ...           [Support, Disabler, Nuker, Durable]
# 3           3  ...  [Carry, Disabler, Jungler, Nuker, Initiator]
# 4           4  ...           [Support, Disabler, Nuker, Jungler]
#
# [5 rows x 8 columns]

# %% [markdown]
# Любым удобным для вас способом создайте dataframe c именем my_data, в котором две колонки c именами (type - строки, value - целые числа) и четыре наблюдения в каждой колонке:
#
#
# type value
# A    10
#
# A    14
#
# B    12
#
# B    23
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %%
d = {'type': ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]}

# %%
my_data=pd.DataFrame(data=d)

# %%
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %% [markdown]
# Особенно важный навык при работе с данными - это умение быстро и эффективно отбирать нужные вам колонки или строки.
#
# Начнем с простого, в dataframe с именем my_stat сохранено 20 строк и четыре колонки (V1, V2, V3, V4):
#
# В переменную с именем subset_1 сохраните только первые 10 строк и только 1 и 3 колонку.
# В переменную с именем subset_2 сохраните все строки кроме 1 и 5 и только 2 и 4 колонку.
#
# Помните, что нумерация индексов строк и колонок начинается с 0.
#
# Обратите внимание, получившиеся subset_1 и subset_2 - тоже должны быть dataframe.
#
# Вы можете скачать набор данных, которые нам также пригодятся в следующих заданиях,  и потренироваться у себя на компьютере. Чтобы считать данные при помощи pandas, используйте функцию read_csv.
#
# import pandas as pd
#
# my_stat = pd.read_csv('my_stat.csv')
#
# Важно понимать, в чем разница между pandas loc и iloc. Как отобрать все строки кроме указанных? Умение искать ответы поможет вам на начальных этапах знакомства с pandas!

# %%
my_stat = pd.read_csv('my_stat.csv')

# %%
my_stat.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
subset_1 = my_stat.iloc[0:10,[0,2]]

# %%
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
subset_2 = my_stat.iloc[:,[1,3]].drop(my_stat.index[[0,4]])

# %%
subset_2
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %% [markdown]
# Теперь потренируемся отбирать нужные нам наблюдения (строки), соответствующие некому условию. В dataframe с именем my_stat четыре колонки V1, V2, V3, V4:
#
# **В переменную subset_1 ** сохраните только те наблюдения, у которых значения переменной V1  строго больше 0, и значение переменной V3  равняется 'A'.
#
# **В переменную  subset_2**  сохраните только те наблюдения, у которых значения переменной V2  не равняются 10, или значения переменной V4 больше или равно 1.
#
# Как и в предыдущей задаче результат фильтрации - это тоже dataframe.
#
# Фильтрацию данных можно осуществить разными способами, например так или так.
#
# https://stackoverflow.com/questions/22086116/how-do-you-filter-pandas-dataframes-by-multiple-columns
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html

# %%
subset_1 = my_stat.query("V1 > 0 & V3 == 'A'")

# %%
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
subset_2 = my_stat.query("V2 != 10 | V4 >= 1")

# %%
subset_2
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %% [markdown]
# Теперь давайте **преобразуем** наши данные. В переменной my_stat лежат данные с которыми вам необходимо проделать следующее дейтвие. В этих данных (my_stat) создайте две новые переменных:
#
# **V5** = V1 + V4
#
# **V6** = натуральный логарифм переменной V2
#
# Где найти натуральный логарифм?

# %%
 my_stat['V5']=my_stat['V1']+my_stat['V4']

# %%
my_stat['V6']=np.log(my_stat['V2'])

# %%
my_stat
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# ..   ..   ... ..  ...  ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442
# 497  -1  11.0  B  2.0  1.0  2.397895
# 498   1  11.0  A  2.0  3.0  2.397895
# 499   0   8.0  B  1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %% [markdown]
# Переменные V1, V2  ... такие имена никуда не годятся. С такими названиями легко запутаться в собственных данных и в результате ошибиться в расчетах.
#
# Переименуйте колонки в данных  my_stat следующим образом:
#
# V1 -> session_value
#
# V2 -> group
#
# V3 -> time
#
# V4 -> n_users

# %%
my_stat=my_stat.rename (columns = {'V1':'session_value','V2' : 'group','V3':'time','V4':'n_users'})

# %%
my_stat
# Out:
#      session_value  group time  n_users   V5        V6
# 0                2   13.0    B      1.0  3.0  2.564949
# 1               -1    7.0    B      1.0  0.0  1.945910
# 2                0   11.0    A      0.0  0.0  2.397895
# 3                2   11.0    A      2.0  4.0  2.397895
# 4                0   10.0    B     -1.0 -1.0  2.302585
# ..             ...    ...  ...      ...  ...       ...
# 495              1    8.0    A     -1.0  0.0  2.079442
# 496              3    8.0    A      1.0  4.0  2.079442
# 497             -1   11.0    B      2.0  1.0  2.397895
# 498              1   11.0    A      2.0  3.0  2.397895
# 499              0    8.0    B      1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %% [markdown]
# И напоследок давайте разберемся, **как заменять наблюдения в данных.**
#
# В dataframe с именем my_stat сохранены данные с 4 колонками: **session_value, group, time, n_users.**
#
# В переменной **session_value** замените все пропущенные значения на нули. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
#
# В переменной **n_users **замените **все отрицательные значения на медианное значение переменной n_users (без учета отрицательных значений, разумеется).**https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.median.html
#
# Как получить медиану переменной n_users без учета отрицательных значений? Если не придумали решения, подсказка - ищите один из возможных ответов в задачах, которые мы уже решили.
#
# Данные для тренировки.

# %%
my_stat1=pd.read_csv('my_stat_1.csv')

# %%
my_stat1.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9

# %%
my_stat1['session_value']=my_stat1.fillna(0)

# %%
my_stat1
# Out:
#   session_value  time group  n_users
# 0             0    12     B        9
# 1             0    11     A       -1
# 2             1     8     A        1
# 3             2     9     B        3
# 4             2    10     B        9
# 5             3     8     A        8
# 6             0    11     B        5
# 7             0     9     A        4
# 8             0     8     B      -11
# 9             0     9     A      -20

# %% [markdown]
# 2) median_n_users = my_stat[...]...median() # вычисление медианы
#
# 3) my_stat.loc[....] = median_n_users

# %%
median_n_users=my_stat1.loc[my_stat1['n_users']>=0]

# %%
users=my_stat1.loc[(my_stat1['n_users']>=0]
# Out:
#   File "<ipython-input-133-d61d2f06097b>", line 1
#     users=my_stat1.loc[(my_stat1['n_users']>=0]
#                                               ^
# SyntaxError: invalid syntax

# %%
my_stat1
# Out:
# session_value    1.0
# time             9.0
# n_users          5.0
# dtype: float64

# %% [markdown]
# #  Stepik ML contest

# %% [markdown]
# events_train.csv - данные о действиях, которые совершают студенты со стэпами
#
#     step_id - id стэпа
#     user_id - анонимизированный id юзера
#     timestamp - время наступления события в формате unix date
#     action - событие, возможные значения:
#
#     discovered - пользователь перешел на стэп
#     viewed - просмотр шага,
#     started_attempt - начало попытки решить шаг, ранее нужно было явно нажать на кнопку - начать решение, перед тем как приступить к решению практического шага
#     passed - удачное решение практического шага
#
#
#
#
# submissions_train.csv - данные о времени и статусах сабмитов к практическим заданиям
#
#     step_id - id стэпа
#     timestamp - время отправки решения в формате unix date
#     submission_status - статус решения
#     user_id - анонимизированный id юзера

# %%
import pandas as pd
import numpy as np
% matplotlib inline
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# настройка графика

# %%
sns.set(rc={'figure.figsize':(9,6)})

# %%
events_data=pd.read_csv('event_data_train.csv')

# %% [markdown]
# обрати внимание - дата записана в **timesstamp uniqsdate.**возможно *хорошо для оптимизации модели*.
# это количество секунд,которые прошли с определенной даты (тут - 1 января 1970)

# %%
events_data.head(10)
# Out:
#    step_id   timestamp           action  user_id
# 0    32815  1434340848           viewed    17632
# 1    32815  1434340848           passed    17632
# 2    32815  1434340848       discovered    17632
# 3    32811  1434340895       discovered    17632
# 4    32811  1434340895           viewed    17632
# 5    32811  1434340895           passed    17632
# 6    32929  1434340921       discovered    17632
# 7    32929  1434340921           viewed    17632
# 8    32929  1434340939  started_attempt    17632
# 9    32929  1434340944           passed    17632

# %% [markdown]
# timestamp можно сравнивать с значениями - !!

# %% [markdown]
# сначала изучаем все данные

# %%
events_data.action.unique()
# Out:
# array(['viewed', 'passed', 'discovered', 'started_attempt'], dtype=object)

# %% [markdown]
# переводим таймстемп в стандартную дату

# %%
events_data['date'] = pd.to_datetime(events_data.timestamp,unit='s')

# %%
events_data.head()
# Out:
#    step_id   timestamp      action  user_id                date
# 0    32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1    32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2    32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3    32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4    32811  1434340895      viewed    17632 2015-06-15 04:01:35

# %% [markdown]
# делаем проверку даты на валидность. начальная дата.

# %%
events_data.date.min()
# Out:
# Timestamp('2015-06-15 04:00:48')

# %%
events_data.date.max()
# Out:
# Timestamp('2018-05-19 23:33:31')

# %% [markdown]
# Работа с временем и датой - очень важный аспект в мире Data Science. Практически все базы данных используют timestamp для определения времени события, в машинном обучении есть целое направление - анализ временных рядов, для аналитики продукта очень важно понимать, как располагаются события во времени.
#
# Подготовил для вас несколько полезных статей:
#
# Работы с датой в Pandas   https://medium.com/datadriveninvestor/how-to-work-with-dates-in-pandas-like-a-pro-a84055a4819d и еще один вариант https://www.geeksforgeeks.org/python-working-with-date-and-time-using-pandas/
#
# Работа с датой в Python при помощи модуля datetime

# %% [markdown]
# создаем колонку "день"

# %%
events_data['day'] = events_data.date.dt.date

# %%
events_data.head()
# Out:
#    step_id   timestamp      action  user_id                date         day
# 0    32815  1434340848      viewed    17632 2015-06-15 04:00:48  2015-06-15
# 1    32815  1434340848      passed    17632 2015-06-15 04:00:48  2015-06-15
# 2    32815  1434340848  discovered    17632 2015-06-15 04:00:48  2015-06-15
# 3    32811  1434340895  discovered    17632 2015-06-15 04:01:35  2015-06-15
# 4    32811  1434340895      viewed    17632 2015-06-15 04:01:35  2015-06-15

# %% [markdown]
# посчитаем кол-во уник. юзеров в день.

# %%
events_data.groupby('day').user_id.nunique().head()
# Out:
# day
# 2015-06-15    705
# 2015-06-16    526
# 2015-06-17    440
# 2015-06-18    411
# 2015-06-19    377
# Name: user_id, dtype: int64

# %%
events_data.groupby('day').user_id.unique().head()
# Out:
# day
# 2015-06-15    [17632, 12494, 442, 22254, 6646, 5681, 19739, ...
# 2015-06-16    [5887, 21007, 25291, 25628, 8538, 20285, 20448...
# 2015-06-17    [5887, 17144, 12372, 26657, 23951, 20448, 1758...
# 2015-06-18    [13293, 899, 26777, 22089, 17585, 22022, 811, ...
# 2015-06-19    [13392, 23951, 17252, 20907, 25628, 1009, 9774...
# Name: user_id, dtype: object

# %% [markdown]
# ***график***

# %%
events_data.groupby('day').user_id.nunique().plot()

# %% [markdown]
# распределение пользоваетелей по количеству балов, которые они набрали за курс.

# %% [markdown]
# "неправильное" решение
# выбриаем юзеров по действию
# групируем по юзерам
# агрегируем по курсу, подсчитываем каунт. не посчитает пользователей, которые не прошли курс. потеряем данные.

# %%
events_data[events_data.action == 'passed'] \
.groupby('user_id' , as_index = False) \
.agg({'step_id':'count'}) \
.rename(columns = {'step_id':'passed_steps'}).head()
# Out:
#    user_id  passed_steps
# 0        2             9
# 1        3            87
# 2        5            11
# 3        7             1
# 4        8            84

# %%
events_data[events_data.action == 'passed'] \
.groupby('user_id' , as_index = False) \
.agg({'step_id':'count'}) \
.rename(columns = {'step_id':'passed_steps'}).passed_steps.hist()

# %% [markdown]
# "правильное" решение - функция агрегации - паева таблица (???) - pivot table
# принимает на вход несколько аргументов:
# колонка - index

# %%
events_data.pivot_table(index='user_id',
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index().head()
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 0             1           1       0                0       1
# 1             2           9       9                2      10
# 2             3          91      87               30     192
# 3             5          11      11                4      12
# 4             7           1       1                0       1

# %%
events_data.pivot_table(index='user_id',
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index().discovered.hist()

# %% [markdown]
# Продолжаем предобрабатывать данные
#
#     В этом уроке познакомимся с merge и join в Pandas https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#     А также рассмотрим продвинутый прием по работе с данными при помощи метода apply  https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html

# %%
submissions_data=pd.read_csv('submissions_data_train.csv')

# %%
submissions_data.head()
# Out:
#    step_id   timestamp submission_status  user_id
# 0    31971  1434349275           correct    15853
# 1    31972  1434348300           correct    15853
# 2    31972  1478852149             wrong    15853
# 3    31972  1478852164           correct    15853
# 4    31976  1434348123             wrong    15853

# %%
submissions_data['date'] = pd.to_datetime(submissions_data.timestamp,unit='s')

# %%
submissions_data['day'] = submissions_data.date.dt.date

# %%
submissions_data.head()
# Out:
#    step_id   timestamp  ...                date         day
# 0    31971  1434349275  ... 2015-06-15 06:21:15  2015-06-15
# 1    31972  1434348300  ... 2015-06-15 06:05:00  2015-06-15
# 2    31972  1478852149  ... 2016-11-11 08:15:49  2016-11-11
# 3    31972  1478852164  ... 2016-11-11 08:16:04  2016-11-11
# 4    31976  1434348123  ... 2015-06-15 06:02:03  2015-06-15
#
# [5 rows x 6 columns]

# %%
users_scores = submissions_data.pivot_table(index='user_id',
                        columns='submission_status', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index().head()

# %%
users_scores
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1

# %% [markdown]
# предскажем пользователей, которые дропнули курс, ушли и не вернулись.понятие пользователя, который ушел нет.
# для каждого пользователя расчитать промежутки в перерывах в курсе, потом принять статистическое решение.

# %% [markdown]
# функция **dop_duplicates()**

# %%
events_data[['user_id','step_id']].head()
# Out:
#    user_id  step_id
# 0    17632    32815
# 1    17632    32815
# 2    17632    32815
# 3    17632    32811
# 4    17632    32811

# %%
events_data[['user_id','step_id']].head().drop_duplicates()
# Out:
#    user_id  step_id
# 0    17632  32815.0
# 3    17632  32811.0

# %% [markdown]
# ```
# 1. возьмем юзера, день, таймстэмп`
# 2. уберем дубликаты для юзера и дня
# 3. соберем для каждого пользователя дни которые он был на курсе и посмотрим перерывы между ними
# 4. с функцией эпплай соберем в список уникальные дни``

# %%
events_data[['user_id','day', 'timestamp']].drop_duplicates(subset=['user_id','day'])\
.groupby('user_id')['timestamp'].apply(list).head()
# Out:
# user_id
# 1                                         [1472827464]
# 2                             [1514383364, 1519226966]
# 3    [1434358476, 1441257725, 1441440209, 144153391...
# 5                             [1466156809, 1499859621]
# 7                                         [1521634660]
# Name: timestamp, dtype: object

# %% [markdown]
# ```
# считаем промежутки между днями функцией np.diff```

# %%
gap_data = events_data[['user_id','day', 'timestamp']].drop_duplicates(subset=['user_id','day'])\
.groupby('user_id')['timestamp'].apply(list)\
.apply(np.diff).values

# %%
np.concatenate(gap_data,axis=0)
# Out:
# array([4843602, 6899249,  182484, ...,   98252,   57019, 1567990])

# %%
gap_data = pd.Series(np.concatenate(gap_data,axis=0))

# %%
gap_data
# Out:
# 0         4843602
# 1         6899249
# 2          182484
# 3           93710
# 4         2768870
#            ...
# 97867    14347289
# 97868      505061
# 97869       98252
# 97870       57019
# 97871     1567990
# Length: 97872, dtype: int64

# %% [markdown]
# разница в днях

# %%
gap_data = gap_data /(24*60*60)

# %%
gap_data[gap_data < 200].hist()

# %%
gap_data.quantile(0.90)
# Out:
# 18.325995370370403

# %% [markdown]
# какое время отсутствия нужно, чтобы оценить пользователя как дропнувшигося

# %% [markdown]
# разметим наших пользователей, являются они дропнувшимися или нет.
# дропнуля- составное условие = не получил сертификат и не заходит на курс более 30 дней.

# %% [markdown]
# смотрим конец данных.данных находим дату окончания курса.

# %%
events_data.tail()
# Out:
#          step_id   timestamp  ...                date         day
# 3547663  33375.0  1526772685  ... 2018-05-19 23:31:25  2018-05-19
# 3547664  32815.0  1526772750  ... 2018-05-19 23:32:30  2018-05-19
# 3547665  32815.0  1526772750  ... 2018-05-19 23:32:30  2018-05-19
# 3547666  32815.0  1526772750  ... 2018-05-19 23:32:30  2018-05-19
# 3547667  33892.0  1526772811  ... 2018-05-19 23:33:31  2018-05-19
#
# [5 rows x 6 columns]

# %% [markdown]
# касательно последнего таймстэмпа будет считывать пользователей.
# касательно каждого пользователя расчитаем макс. таймстэмп - макс. время появления на курсе.

# %%
events_data.groupby('user_id')\
.agg({'timestamp':"max"}).head()
# Out:
#           timestamp
# user_id
# 1        1472827464
# 2        1519226966
# 3        1444581588
# 5        1499859939
# 7        1521634660

# %% [markdown]
# является ли таймстэмп больше чем наш предел в месяц.

# %%
30*24*60*60
# Out:
# 2592000

# %% [markdown]
# сколько времени прошло с момента его посещения на текущий день(последняя дата курса).

# %%
users_data = events_data.groupby('user_id', as_index=False)\
.agg({'timestamp':"max"}).rename(columns={'timestamp':'last_timestamp'})

# %%
now = 1521634660
drop_out_threshold = 2592000

# %%
users_data.head()
# Out:
#    user_id  last_timestamp
# 0        1      1472827464
# 1        2      1519226966
# 2        3      1444581588
# 3        5      1499859939
# 4        7      1521634660

# %% [markdown]
# ```
# 1521634660 - final timestamp. сколько времени прошло с последнего посешения пользователя по сравнению с текущим таймстэмпом.
# обернем в "1" или "0" в зависимости от того больше ли оно порогового значения или меньше.
# ```

# %%
users_data['is_gone_user'] = 1521634660 - users_data.last_timestamp

# %%
users_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user
# 0        1      1472827464      48807196
# 1        2      1519226966       2407694
# 2        3      1444581588      77053072
# 3        5      1499859939      21774721
# 4        7      1521634660             0

# %% [markdown]
# обернем в "1" или "0" в зависимости от того больше ли оно порогового значения или меньше.

# %%
users_data['is_gone_user'] = (now - users_data.last_timestamp)>drop_out_threshold

# %%
users_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user
# 0        1      1472827464          True
# 1        2      1519226966         False
# 2        3      1444581588          True
# 3        5      1499859939          True
# 4        7      1521634660         False

# %% [markdown]
# нужно добавить условие - прошел ли юзер курс или нет.
# добавим число попыток, кол-во балов, т.д.

# %%
users_scores.head()
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1

# %%
users_data.head()
# Out:
#          last_timestamp  is_gone_user
# user_id
# 1            1472827464          True
# 2            1519226966         False
# 3            1444581588          True
# 5            1499859939          True
# 7            1521634660         False

# %%
users_data = users_data.merge(users_scores, on = 'user_id', how = 'outer')
# Out:
#        user_id  last_timestamp  is_gone_user  ...  wrong_y  correct  wrong
# 0            1      1472827464          True  ...      NaN      NaN    NaN
# 1            2      1519226966         False  ...      0.0      2.0    0.0
# 2            3      1444581588          True  ...     23.0     29.0   23.0
# 3            5      1499859939          True  ...      2.0      2.0    2.0
# 4            7      1521634660         False  ...      NaN      NaN    NaN
# ...        ...             ...           ...  ...      ...      ...    ...
# 19229    26790      1517495987          True  ...      NaN      NaN    NaN
# 19230    26793      1510225034          True  ...      NaN      NaN    NaN
# 19231    26794      1512035039          True  ...      NaN      NaN    NaN
# 19232    26797      1509995096          True  ...      NaN      NaN    NaN
# 19233    26798      1520978742         False  ...      NaN      NaN    NaN
#
# [19234 rows x 13 columns]

# %%
users_data
# Out:
#        user_id  last_timestamp  is_gone_user  ...  wrong_x  correct_y  wrong_y
# 0            1      1472827464          True  ...      NaN        NaN      NaN
# 1            2      1519226966         False  ...      0.0        2.0      0.0
# 2            3      1444581588          True  ...     23.0       29.0     23.0
# 3            5      1499859939          True  ...      2.0        2.0      2.0
# 4            7      1521634660         False  ...      NaN        NaN      NaN
# ...        ...             ...           ...  ...      ...        ...      ...
# 19229    26790      1517495987          True  ...      NaN        NaN      NaN
# 19230    26793      1510225034          True  ...      NaN        NaN      NaN
# 19231    26794      1512035039          True  ...      NaN        NaN      NaN
# 19232    26797      1509995096          True  ...      NaN        NaN      NaN
# 19233    26798      1520978742         False  ...      NaN        NaN      NaN
#
# ...

# %%
users_data.drop(['correct_x','wrong_x','correct_y', 'wrong_y'] , axis=1)
# Out:
#        user_id  last_timestamp  is_gone_user
# 0            1      1472827464          True
# 1            2      1519226966         False
# 2            3      1444581588          True
# 3            5      1499859939          True
# 4            7      1521634660         False
# ...        ...             ...           ...
# 19229    26790      1517495987          True
# 19230    26793      1510225034          True
# 19231    26794      1512035039          True
# 19232    26797      1509995096          True
# 19233    26798      1520978742         False
#
# [19234 rows x 3 columns]

# %% [markdown]
# # Деревья решений. Часть 3.

# %%
from sklearn import tree
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
data = pd.DataFrame({'X_1': [1, 1, 1, 0, 0, 0, 0, 1], 'X_2': [0, 0, 0, 1, 0, 0, 0, 1], 'Y': [1, 1, 1, 1, 0, 0, 0, 0]})

# %%
data
# Out:
#    X_1  X_2  Y
# 0    1    0  1
# 1    1    0  1
# 2    1    0  1
# 3    0    1  1
# 4    0    0  0
# 5    0    0  0
# 6    0    0  0
# 7    1    1  0

# %% [markdown]
# создаем объект. дерево решений - это объект, у которого есть методы (обучиться, предсказать и т.п.), атрибуты, как и пандовский датафрейм.

# %%
clf=tree.DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# посмотрим что внутри объекта

# %%
clf
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
сделаем предобработку данных.

# %%
X=data[['X_1', 'X_2']]

# %%
y=data.Y

# %% [markdown]
# обучение дерева с помощью метода fit

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dot_data = StringIO()

# %%
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# 2.2 Немного теории и энтропии
# Представьте, что вы решили научить робота для животных отличать собачек от котиков. Для начала проанализируем данные - отметьте все верные утверждения о данном датафрэйме

# %%
df=pd.read_csv('dogs.csv', index_col=0)

# %%
df
# Out:
#    Шерстист  Гавкает  Лазает по деревьям      Вид
# 0         1        1                   0  собачка
# 1         1        1                   0  собачка
# 2         1        1                   0  собачка
# 3         1        1                   0  собачка
# 4         1        0                   1    котик
# 5         1        0                   1    котик
# 6         1        0                   1    котик
# 7         1        0                   1    котик

# %%
clf=tree.DecisionTreeClassifier(criterion='entropy',min_samples_split=3)

# %%
X=df[['Шерстист', 'Гавкает', 'Лазает по деревьям']]

# %%
y=df.Вид

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=3,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

# %%
from IPython.display import HTML
style = "<style>svg{width:70% !important;height:70%; !important;}</style>"
HTML(style)
# Out:
# <style>svg{width:70% !important;height:70%; !important;}</style>

# %%
graph = Source(tree.export_graphviz(clf, out_file=None,
                                    feature_names=list(X),
                                    class_names=['Negative', 'Positive'],
                                    filled=True))
display(SVG(graph.pipe(format='svg')))

# %% [markdown]
# # Titanic competition

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree

# %%
titanic_data=pd.read_csv('train.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# делаем базовую предобработку.
#
# проверяем пропущенные значения.

# %%
titanic_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# удалеяем ненужные колонки

# %%
X=titanic_data.drop(['PassengerId','Name','Survived','Ticket','Cabin'], axis=1)
y=titanic_data.Survived

# %% [markdown]
# делаем лэйблы для пола. метод панды - get dummies

# %%
X=pd.get_dummies(X)

# %% [markdown]
# заполняем пустые значения в возрасте медианой

# %%
X=X.fillna({'Age':X.Age.median()})

# %%
# Out:
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_female    0
# Sex_male      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
clf=tree.DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.33,random_state=42)

# %%
X_train.shape
# Out:
# (596, 10)

# %% [markdown]
# score - предсказывает число правильных ответов

# %%
clf.score(X,y)
# Out:
# 0.8226711560044894

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.score(X_train,y_train)
# Out:
# 0.8238255033557047

# %%
clf.fit(X_test,y_test)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.score(X_test,y_test)
# Out:
# 0.8203389830508474

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.score(X_train,y_train)
# Out:
# 0.8238255033557047

# %%
clf.fit(X_test,y_test)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.score(X_train,y_train)
# Out:
# 0.7969798657718121

# %% [markdown]
# заведем масив параметров, с которыми мы поработаем.

# %%
max_depth_values=range(1,100)

# %% [markdown]
# для каждого значения в массиве параметров, мы хотим инициировать классификатор с указанной глубиной, обучаться на трейн выборке, предсказывать точность класификации на трейн выборке, предсказывать точность классификации на тест выборке. Сохраним в переменную. в конце сохраним в датафрейм, чтобы визуализировать, чтобы увидеть какой параметр глубины дерева показал себя максимально хорошо. scores_data - пустой датафрейм, который будем постепенно наращивать. внутри цикла заведем временный датафрейм, чтобы посмотреть значения.

# %%
max_depth_values = range(1, 100)

# %%
scores_data = pd.DataFrame()

# %%
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    
    mean_cross_val_score = cross_val_score(clf, X_train, y_train , cv=5).mean()
    
    temp_score_data = pd.DataFrame({'max_depth': [max_depth],
                                    'train_score': [train_score],
                                    'test_score': [test_score],
                                    'cross_val_score': [mean_cross_val_score]})
    scores_data = scores_data.append(temp_score_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-b58aea2805de> in <module>()
#       5     test_score = clf.score(X_test, y_test)
#       6
# ----> 7     mean_cross_val_score = cross_val_score(clf, X_train, y_train , cv=5).mean()
#       8
#       9     temp_score_data = pd.DataFrame({'max_depth': [max_depth],
#
# NameError: name 'cross_val_score' is not defined

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score  cross_val_score
# 0          1     0.781879    0.796610         0.781961
# 0          2     0.805369    0.776271         0.770196
# 0          3     0.823826    0.820339         0.790322
# 0          4     0.833893    0.823729         0.788627
# 0          5     0.840604    0.806780         0.800392

# %% [markdown]
# для визуализации - метод melt https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.melt.html

# %%
scores_data_long = pd.melt(scores_data, id_vars=['max_depth'], value_vars=['train_score','test_score','cross_val_score'],
var_name='set_type', value_name='score')

# %%
scores_data_long.head()
# Out:
#    max_depth     set_type     score
# 0          1  train_score  0.781879
# 1          2  train_score  0.805369
# 2          3  train_score  0.823826
# 3          4  train_score  0.833893
# 4          5  train_score  0.840604

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
sns.lineplot(x="max_depth", y="score", hue="set_type", data=scores_data_long)

# %% [markdown]
# cross-validation

# %%
from sklearn.model_selection import cross_val_score

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %% [markdown]
# ```
# clf - название классификатора,
# X_train,y_train - данные
# ```cv=5 - количество фолдов, на которые разбиваются данные
#
# array([0.75833333, 0.78991597, 0.78151261, 0.81512605, 0.80672269]) - точность значений, который получил классификатор, разбив данные на 5 равных кусочков.
# используем mean(), чтобы получить среднюю точность на кросс валидации.

# %%
cross_val_score(clf,X_train,y_train, cv=5)
# Out:
# array([0.75833333, 0.78991597, 0.78151261, 0.81512605, 0.80672269])

# %%
cross_val_score(clf,X_train,y_train, cv=5).mean()
# Out:
# 0.7903221288515405

# %%
scores_data_long.query("set_type == 'cross_val_score'").head()
# Out:
#      max_depth         set_type     score
# 198          1  cross_val_score  0.781961
# 199          2  cross_val_score  0.770196
# 200          3  cross_val_score  0.790322
# 201          4  cross_val_score  0.788627
# 202          5  cross_val_score  0.800392

# %%
best_clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=11)

# %%
cross_val_score(clf,X_test,y_test, cv=5).mean()
# Out:
# 0.7694915254237289

# %% [markdown]
# # Практика. Ирис.

# %% [markdown]
# Убедимся в том, что всё так происходит на самом деле. **Скачайте тренировочный датасэт с ирисами, обучите деревья с глубиной от 1 до 100**. Целевой переменной при обучении является переменная **species**. При этом записывайте его скор (DecisionTreeClassifier.score()) на тренировочных данных, и аккуратность предсказаний (accuracy_score) на тестовом датасэте. Затем визуализируйте зависимость скора и аккуратности предсказаний от глубины дерева и выберите правильную визуализацию из предложенных.
#
# Важно: задайте random seed прямо перед созданием дерева или укажите его в параметрах дерева (random_state=rs)
#
# np.random.seed(0)
# my_awesome_tree = DecisionTreeClassifier(...)
#
# или
#
# my_awesome_tree = DecisionTreeClassifier(random_state=0, ...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
test_iris=pd.read_csv('test_iris.csv', index_col=0)

# %%
train_iris=pd.read_csv('train_iris.csv',index_col=0)

# %%
test_iris.head()
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 114           5.8          2.8           5.1          2.4        2
# 70            5.9          3.2           4.8          1.8        1
# 138           6.0          3.0           4.8          1.8        2
# 59            5.2          2.7           3.9          1.4        1
# 44            5.1          3.8           1.9          0.4        0

# %% [markdown]
# предобработка данных

# %% [markdown]
# проверяем значения

# %%
test_iris.isnull()
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 114         False        False         False        False    False
# 70          False        False         False        False    False
# 138         False        False         False        False    False
# 59          False        False         False        False    False
# 44          False        False         False        False    False
# 125         False        False         False        False    False
# 36          False        False         False        False    False
# 141         False        False         False        False    False
# 12          False        False         False        False    False
# 63          False        False         False        False    False
# 106         False        False         False        False    False
# 96          False        False         False        False    False
# 103         False        False         False        False    False
# ...

# %% [markdown]
# убираем ненужные колонки. устанав. целевую переменную.

# %% [markdown]
# разбиваем на тест/трейн сэт

# %%
X_train=train_iris.drop(['species'], axis=1)

# %%
X_test=test_iris.drop(['species'], axis=1)

# %%
y_train=train_iris.species

# %%
y_test=test_iris.species

# %%
rs=np.random.seed(0)

# %%
max_depth_values = range(1, 100)

# %%
scores_data = pd.DataFrame()

# %%
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier(random_state=0,criterion='entropy', max_depth=max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    
    mean_cross_val_score = cross_val_score(clf, X_train, y_train , cv=5).mean()
    
    temp_score_data = pd.DataFrame({'max_depth': [max_depth],
                                    'train_score': [train_score],
                                    'test_score': [test_score],
                                    'cross_val_score': [mean_cross_val_score]})
    scores_data = scores_data.append(temp_score_data)

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score  cross_val_score
# 0          1         0.70        0.60             0.70
# 0          2         0.97        0.94             0.95
# 0          3         0.99        0.94             0.96
# 0          4         1.00        0.92             0.96
# 0          5         1.00        0.92             0.96

# %%
scores_data_long = pd.melt(scores_data, id_vars=['max_depth'], value_vars=['train_score','test_score','cross_val_score'],
var_name='set_type', value_name='score')

# %%
import seaborn as sns

# %%
sns.lineplot(x="max_depth", y="score", hue="set_type", data=scores_data_long)

# %% [markdown]
# # Практика. Кошки и собаки.

# %% [markdown]
# Мы собрали побольше данных о котиках и собачках, и готовы обучить нашего робота их классифицировать! Скачайте тренировочный датасэт и  обучите на нём Decision Tree. После этого скачайте датасэт из задания и предскажите какие наблюдения к кому относятся. Введите число собачек в вашем датасэте.
#
# В задании допускается определённая погрешность.
#
# P. S.: данные в задании находятся в формате json, используйте метод pd.read_json для их прочтения

# %%
dogs_test=pd.read_csv('dogs_n_cats.csv')

# %%
dogs_test
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0       15    18.0         1        1                   0  собачка
# 1       20    24.0         1        0                   0  собачка
# 2       34    40.8         1        1                   0  собачка
# 3       26    31.2         1        1                   0  собачка
# 4       16    19.2         1        1                   0  собачка
# ..     ...     ...       ...      ...                 ...      ...
# 995      8     3.2         1        0                   1    котик
# 996      7     2.8         1        0                   1    котик
# 997      6     2.4         1        0                   1    котик
# 998      7     2.8         1        0                   1    котик
# 999     11     4.4         1        0                   1    котик
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Метрики качества

# %% [markdown]
# Возвращаемся к дэйтингу, некий Анатолий зарегистрировался в приложении знакомств, некий алгоритм на основе машинного обучения порекомендовал Анатолию 30 фотографий из 100. Анатолий лайкнул 15 фотографий из 30 предложенных, в дальнейшем выяснилось, что Анатолий мог бы лайкнуть еще 30 фотографий из 70 непредложенных.
#
# Будем считать, что  лайк Анатолия является положительным исходом, а отсутствие лайка - отрицательным. Соответственно предсказанный лайк, совпавший с реальным - True positive, предсказанный лайк, не завершившийся реальным лайком - False positive и т. д. Давайте оценим работу алгоритма с точки зрения метрик качества модели.
#
#
#
#
#
#
# Такой формат представления предсказания модели и реальных исходов называется confusion matrix. Глядя на такую таблицу, легко можно понять, где именно ошибается наша модель. А также рассчитать различные метрики качества модели.
#
#     Precision
#     Recall
#     F1 score

# %% [markdown]
# предсказанный лайк, совпавший с реальным - True positive
# предсказанный лайк, не завершившийся реальным лайком - False positive.
# TP=15
# FP=15
# FN=30
# TN=40

# %% [markdown]
# The precision is the ratio tp / (tp + fp) where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.
#
# The best value is 1 and the worst value is 0.
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score

# %%
import pandas as pd
import numpy as np

# %%
TP=15
FP=15
FN=30
TN=40

# %%
precision=TP/(TP+FP)

# %%
precision
# Out:
# 0.5

# %% [markdown]
# Recall
# Compute the recall.
#
# The recall is the ratio tp / (tp + fn) where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.
#
# The best value is 1 and the worst value is 0.
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html#sklearn.metrics.recall_score

# %%
recall=TP/(TP+FN)

# %%
recall
# Out:
# 0.3333333333333333

# %% [markdown]
# ompute the F1 score, also known as balanced F-score or F-measure.
#
# The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0. The relative contribution of precision and recall to the F1 score are equal. The formula for the F1 score is:
# F1 = 2 * (precision * recall) / (precision + recall)
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html

# %%
F1 = 2 * (precision * recall) / (precision + recall)

# %%
F1
# Out:
# 0.4

# %% [markdown]
# Поупражняемся в расчётах precision. В задании даны переменные, содержащие информацию о песнях и артистах - X_train, y_train, X_test и y_test. Исходно в датасэтах содержались тексты песен, но Decision Tree работает с категориальными и числовыми переменными, а текст это... текст. Поэтому его необходимо преобразовать в понятную для модели форму. В данном случае для каждой песни просто посчитаны длина и количество некоторых знаков пунктуации.
#
# Обучите модель на тренировочных данных, предскажите авторов для тестовых и поместите в переменную predictions. Затем посчитайте precision score на предсказаниях и y_test, укажите параметр average='micro', и сохраните результат в переменную precision.
#
# Если он будет недостаточно высок, потюньте немного модель.
#
# Исходные данные взяты отсюда, слегка процессированные можно взять здесь (исходные колонки типа жанра, года были выкинуты в задании)

# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
songs=pd.read_csv('songs.csv')

# %%
songs.head()
# Out:
#                    song  year          artist  ... exclamations colons  hyphens
# 0            the-ownerz  2007       gangstarr  ...            5      0       11
# 1  dead-sound-of-misery  2006  blind-guardian  ...            0      0        0
# 2         modred-s-song  2006  blind-guardian  ...            0      1        0
# 3        the-ninth-wave  2015  blind-guardian  ...            0      0        0
# 4                skills  2014       gangstarr  ...            0      0        3
#
# [5 rows x 10 columns]

# %%
X=songs.drop(['artist'], axis=1)
y=songs.artist

# %%
X=pd.get_dummies(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.33,random_state=42)

# %%
max_depth_values = range(1, 100)

# %%
scores_data = pd.DataFrame()

# %%
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier(random_state=0,criterion='entropy', max_depth=max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    
    mean_cross_val_score = cross_val_score(clf, X_train, y_train , cv=5).mean()
    
    temp_score_data = pd.DataFrame({'max_depth': [max_depth],
                                    'train_score': [train_score],
                                    'test_score': [test_score],
                                    'cross_val_score': [mean_cross_val_score]})
    scores_data = scores_data.append(temp_score_data)

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score  cross_val_score
# 0          1     0.726141    0.638655          0.72619
# 0          2     1.000000    1.000000          1.00000
# 0          3     1.000000    1.000000          1.00000
# 0          4     1.000000    1.000000          1.00000
# 0          5     1.000000    1.000000          1.00000

# %% [markdown]
# # Подбор параметров и ROC and Roll

# %% [markdown]
# *GridsearCV*

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
parametrs={'criterion':['gini','entropy'], 'max_depth':range(1,30)}

# %%
grid_search_cv_clf=GridSearchCV(clf,parametrs,cv=5)

# %%
grid_search_cv_clf
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
grid_search_cv_clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
grid_search_cv_clf.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5}

# %%
best_clf=grid_search_cv_clf.best_estimator_

# %%
best_clf
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
best_clf.score(X_test,y_test)
# Out:
# 0.8067796610169492

# %%
from sklearn.metrics import precision_score, recall_score

# %%
y_pred = best_clf.predict(X_test)

# %%
precision_score(y_test,y_pred)
# Out:
# 0.7889908256880734

# %%
recall_score(y_test,y_pred)
# Out:
# 0.7166666666666667

# %% [markdown]
# посмотрим что хранится в предсказаниях нашего дерева. предсказанная вероятность отнесение одному из 2-х классов. для того, чтобы вытащить вероятность, воспользуемся методом предиктид пробы. результат - двумерный массив - вероятность отнесения каждого пассажира к одному из двух классов - выживший или нет.

# %%
y_predicted_prob = best_clf.predict_proba(X_test)

# %%
y_predicted_prob
# Out:
# array([[0.875     , 0.125     ],
#        [0.875     , 0.125     ],
#        [0.875     , 0.125     ],
#        [0.        , 1.        ],
#        [0.49056604, 0.50943396],
#        [0.5       , 0.5       ],
#        [0.49056604, 0.50943396],
#        [0.875     , 0.125     ],
#        [0.49056604, 0.50943396],
#        [0.        , 1.        ],
#        [0.44      , 0.56      ],
#        [0.875     , 0.125     ],
#        [1.        , 0.        ],
#        [0.875     , 0.125     ],
#        [0.875     , 0.125     ],
#        [0.        , 1.        ],
#        [0.75      , 0.25      ],
#        [0.49056604, 0.50943396],
#        [0.875     , 0.125     ],
#        [1.        , 0.        ],
#        [0.875     , 0.125     ],
#        [0.67647059, 0.32352941],
#        [0.49056604, 0.50943396],
#        [0.875     , 0.125     ],
#        [0.875     , 0.125     ],
#        [0.875     , 0.125     ],
#        [0.67647059, 0.32352941],
#        [0.875     , 0.125     ],
# ...
